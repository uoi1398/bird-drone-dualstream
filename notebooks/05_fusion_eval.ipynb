# %%
# %cd /content/bird_drone_dualstream

# %%
# !ls runs/20260515_rgb_seed42
# !ls runs/20260515_flow_seed42

# %%
# !ls runs/20260515_rgb_seed42
# !ls runs/20260515_flow_seed42

# %%
# !python src/evaluate.py --config configs/fusion.yaml

# %%
import pandas as pd

main_results = pd.read_csv("outputs/tables/main_results.csv")
display(main_results)

# %%
alpha_df = pd.read_csv("outputs/tables/val_alpha_selection.csv")
display(alpha_df)

# %%
pred_df = pd.read_csv("outputs/predictions/test_predictions_all_conditions.csv")
display(pred_df.head())
